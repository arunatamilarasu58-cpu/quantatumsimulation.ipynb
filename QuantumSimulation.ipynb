# %% [markdown]
# <a href="https://colab.research.google.com/github/arunatamilarasu58-cpu/quantatumsimulation.ipynb/blob/main/QuantumSimulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit
# !pip install qiskit-aer
# !pip install matplotlib
# !pip install pylatexenc
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 43.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 53.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 91.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 5.5 MB/s eta 0:00:00
# ...

# %%
from qiskit import QuantumRegister
from qiskit import ClassicalRegister
from qiskit import QuantumCircuit

# %%
qr = QuantumRegister(1, 'q')
cr = ClassicalRegister(1, 'c')
qc = QuantumCircuit(qr, cr)

qc.h(qr[0])
qc.y(qr[0])
qc.p(3.14/2, qr[0])

qc.measure(qr, cr)

qc.draw('mpl')

# %%
from qiskit_aer import AerSimulator

# %%
from qiskit_aer import AerSimulator
sim = AerSimulator(shots=1024)
jop = sim.run(qc)
res = jop.result()
out = res.get_counts()
print(out)
# Out:
# {'1': 517, '0': 507}

# %%
from qiskit.visualization import plot_histogram

plot_histogram(out)
